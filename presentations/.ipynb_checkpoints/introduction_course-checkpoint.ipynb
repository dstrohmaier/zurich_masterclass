# %% [markdown]
# # Philosophy of AI: Concepts in Machines
#
# David Strohmaier, ALTA Institute, University of Cambridge
#
# ds858@cam.ac.uk
# <br>
# <br>
#
# *"We offer no explanation as to why these architectures seem to work; we attribute their success, as all else, to divine benevolence."*  ~ Shazeer (2020)

# %% [markdown]
# # Introducing Myself

# %% [markdown]
# ## A brief CV
#
# - 2018 PhD in philosophy @ Sheffield.
#     + On issues in philosophy of the social sciences/social ontology
# - 2019 MPhil Advances Computer Science @ Cambridge
# - Stayed on as research associate in CS
# - Started 2023 PhD in CS @ Cambridge
#     + Modelling L2 lexical semantics with machine learning methods

# %% [markdown]
# # What am I on about
#
# The large area of interest:
#
# > Cognitive processes as computational processes that occur in a social context
#
#
# Specific area of research:
#
# > Lexical semantic regularities modelled using AI methods.

# %% [markdown]
# # This Masterclass
#
# - Approach AI from the perspective of concepts
# - Word meanings as concepts

# %% [markdown]
# ## Goals
#
# 1.

# %% [markdown]
# ## Procedure
#
# 1. Start with hands-on experience (day 1 and first half of day 2)
# 2. Look at the intra-discipline debates about AI and meaning (second half of day 2)
# 3. Dive into the grounding problem as an example of a philosophical debate (second half of day 2 and first half o
# 4. Turn to cutting-edge issues in AI research and their philosophical
#     - More open issues and debate

# %% [markdown]
# ## Connections to  topics in philosophy
#
# - Philosophy of AI
#     + Philosophy of science: What counts as a successful model of meaning?
#     + Philosophy of cognitive science: What notion of representation is at play?
#     + AI Ethics: How to interpret patterns in AI models and their limits
