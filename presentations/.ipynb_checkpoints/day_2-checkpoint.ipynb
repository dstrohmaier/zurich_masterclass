# %% [markdown]
# # Day 2
#
# David Strohmaier, ALTA Institute, University of Cambridge
#
# ds858@cam.ac.uk

# %% [markdown]
# ## Plan for the Day: First Half
#
# - Addendum to yesterday
# - (Re-)reading the papers
# - Bender & Koller (2020)
#     - Short presentation by me
#     - Group discussion
#
# **Lunch Break**

# %% [markdown]
# ## Plan for the Day: Second Half:
#
# - Titus (2024)
#     - Short presentation by me
#     - Group discussion
# - Discussion by Philipp
# - Open debate (add questions!)

# %% [markdown]
# ## Addendum: Explanations and Visualisation of Transformer LLMs
# - Another explanation of attentions by 3brown1blue: https://youtu.be/eMlx5fFNoYc
# - Blog post with illustrations of key components of LLMs: https://jalammar.github.io/illustrated-transformer/
# - Interactive visualisation: https://bbycroft.net/llm
